# %%
import pandas as pd

DATA_SOURCE = r'../data/census.csv'

df = pd.read_csv(DATA_SOURCE)

# %%
### USING SKLEARN ###

"""
We will use feature_engine for now.
"""

# from sklearn.preprocessing import KBinsDiscretizer

# DATA_SOURCE = r'../data/census.csv'
# df = pd.read_csv(DATA_SOURCE)

# age_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
# hpw_discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')

# # df['age'] = age_discretizer.fit_transform(df[['age']])
# # df['hours-per-week'] = hpw_discretizer.fit_transform(df[['hours-per-week']])

# df['age'] = age_discretizer.fit_transform(df[['age']])
# df['hours-per-week'] = hpw_discretizer.fit_transform(df[['hours-per-week']])


# print(df['age'].value_counts())
# print(df['hours-per-week'].value_counts())
# Out:
# '\nWe will use feature_engine for now.\n'

# %%
### USING FEATURE ENGINE ###

from feature_engine.discretisers import EqualWidthDiscretiser, EqualFrequencyDiscretiser

DATA_SOURCE = r'../data/census.csv'
df = pd.read_csv(DATA_SOURCE)

age_discretiser = EqualWidthDiscretiser(bins=10, variables=['age'])
hpw_discretiser = EqualFrequencyDiscretiser(q=5, variables=['hours-per-week'])

df = age_discretiser.fit_transform(df)
df = hpw_discretiser.fit_transform(df)

# print(df['age'].value_counts())
# print(df['hours-per-week'].value_counts())

# %%
df['hours-per-week'].value_counts()
# Out:
# 1    16100
# 0     6880
# 3     6491
# 2     3090
# Name: hours-per-week, dtype: int64

# %%
df
# Out:
#             date  age          workclass  population-wgt    education  \
# 0       1-May-53    3          State-gov           77516    Bachelors
# 1      2/14/1994    4   Self-emp-not-inc           83311    Bachelors
# 2      1/21/1964    2            Private          215646      HS-grad
# 3      1/21/1994    4            Private          234721         11th
# 4      1/21/1994    1            Private          338409    Bachelors
# ...          ...  ...                ...             ...          ...
# 32556  2/14/1994    1            Private          257302   Assoc-acdm
# 32557   1-May-93    3            Private          154374      HS-grad
# 32558  2/14/1964    5            Private          151910      HS-grad
# 32559  2/14/1904    0            Private          201490      HS-grad
# 32560  2/14/1993    4       Self-emp-inc          287927      HS-grad
#
#        education-num       marital-status          occupation    relationship  \
# ...

# %%
df
# Out:
#             date  age          workclass  population-wgt    education  \
# 0       1-May-53    3          State-gov           77516    Bachelors
# 1      2/14/1994    4   Self-emp-not-inc           83311    Bachelors
# 2      1/21/1964    2            Private          215646      HS-grad
# 3      1/21/1994    4            Private          234721         11th
# 4      1/21/1994    1            Private          338409    Bachelors
# ...          ...  ...                ...             ...          ...
# 32556  2/14/1994    1            Private          257302   Assoc-acdm
# 32557   1-May-93    3            Private          154374      HS-grad
# 32558  2/14/1964    5            Private          151910      HS-grad
# 32559  2/14/1904    0            Private          201490      HS-grad
# 32560  2/14/1993    4       Self-emp-inc          287927      HS-grad
#
#        education-num       marital-status          occupation    relationship  \
# ...

# %%
help(EqualFrequencyDiscretiser)
# Out:
# Help on class EqualFrequencyDiscretiser in module feature_engine.discretisers:
#
# class EqualFrequencyDiscretiser(feature_engine.base_transformers.BaseNumericalTransformer)
#  |  EqualFrequencyDiscretiser(q=10, variables=None, return_object=False, return_boundaries=False)
#  |
#  |  The EqualFrequencyDiscretiser() divides continuous numerical variables
#  |  into contiguous equal frequency intervals, that is, intervals that contain
#  |  approximately the same proportion of observations.
#  |
#  |  The interval limits are determined using pandas.qcut(), in other words,
#  |  the interval limits are determined by the quantiles. The number of intervals,
#  |  i.e., the number of quantiles in which the variable should be divided is
#  |  determined by the user.
#  |
#  |  The EqualFrequencyDiscretiser() works only with numerical variables.
#  |  A list of variables can be passed as argument. Alternatively, the discretiser
# ...
